# %% [markdown]
# <a href="https://colab.research.google.com/github/ed-tq/Python-Word-Guessing-Console-Game/blob/main/Word_Guessing_Console_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

HTML('''
<script>
function toggleCode() {
    var code = document.querySelectorAll('div.input');
    for (var i = 0; i < code.length; i++) {
        code[i].style.display = code[i].style.display === 'none' ? 'block' : 'none';
    }
}
</script>

<button onclick="toggleCode()">Show/Hide Code</button>
''')
# Out:
# <script>
# function toggleCode() {
#     var code = document.querySelectorAll('div.input');
#     for (var i = 0; i < code.length; i++) {
#         code[i].style.display = code[i].style.display === 'none' ? 'block' : 'none';
#     }
# }
# </script>
#
# <button onclick="toggleCode()">Show/Hide Code</button>

# %% [markdown]
# **Disclaimer**
# *   It is important you do the steps in order.
# *   Type your code in the box/cell where is says '# Type your code below then run:'.
# *   Always run your code first (click the play button next to the code on hover) before running the test code. Always do this when you edit your code.
# ![Run code play button.png](data:image/png;base64,...)
# *   If your code passes the test code you should get all ✅,  else ❌ look at errors to edit your code.
# *   You are encouraged to attempt before using 💡hints.

# %% [markdown]
# #**Step 1: Download Word File**
#
# *   Run the code below to download the `words.txt` file for use in our code.
#
#     <details>
#     The `words.txt` file contains 5-letter words, with each word on a separate line. Only the words in this file are valid guesses for the user.
#     </details>

# %%
# !wget https://raw.githubusercontent.com/ed-tq/Python-Word-Guessing-Console-Game/refs/heads/main/words.txt

# %% [markdown]
# Test to see if word file was downloaded successfully by running the code block below:

# %%
# @title
try:
  with open("words.txt", "r") as f:
    file = f.read()
    print("✅ Word file downloaded successfully!")
except FileNotFoundError:
  print("❌ Word file download unsuccessful")
# Out:
# ✅ Word file downloaded successfully!

# %% [markdown]
# #**Step 2: `Import` Modules**
#
# Import the random module so we can use it to get random words from our words.txt file.

# %%
# Type your code below then run:
import random

# %% [markdown]
# Test your code by running the code below:

# %%
# @title
#Run to test you code - Only run when you have run your code:
try:
    random.randint(1, 10)
    print("✅ Module imported!")
except NameError:
    print ("❌ Module not imported")
# Out:
# ✅ Module imported!

# %% [markdown]
# #**Step 3: Define 'get_started` function**
#
#
# 1.   This function stores name of the word file in a variable.
# 2.   Asks for user name.
# 3.   Prints:
#
# ```
# Welcome to Wordle 101 [userName]
#
# ========================================================================
#                                  Rules
# You have 6 guesses to figure out the solution.
# All solutions are words that are 5 letters long.
# Letters that have been guessed correctly are displayed in uppercase.
# Letters that are in the word but have been guessed in the wrong location
# are displayed in lowercase.
# ========================================================================
# ```
# 4.  Returns file name

# %%
# Type your code below then run:

# %% [markdown]
# ---
# <details>
# <summary>💡Hint</summary>
#
# *   Use variables to store input from prompts `input()`.
#
# *   Copy and paste if needed.
#
# *   You can use `\n` in long sentences to continue sentence in a new line.
#
# *   [userName] should be the name entered by user.
#         <details>
#         <summary>More</summary>
#
#         *   use `print(f"Hello {variable_name}!")` to print a variable in a string. Works for any variable type (e.g. str, int)
#         </details>
#
#
# </details>
#
# ---

# %% [markdown]
# Test your code output:

# %%
# @title
import io
import sys


original_stdout = sys.stdout
original_input = __builtins__.input
captured_output = io.StringIO()

try:
    user_input = "Student"
    sys.stdout = captured_output
    __builtins__.input = lambda _: user_input

    test_function = get_started()
    output = captured_output.getvalue()

    expected_output = """
Welcome to Wordle 101 Student

========================================================================
                                 Rules
You have 6 guesses to figure out the solution.
All solutions are words that are 5 letters long.
Letters that have been guessed correctly are displayed in uppercase.
Letters that are in the word but have been guessed in the wrong location
are displayed in lowercase.
========================================================================

"""

except Exception as e:
    error = e

finally:
    sys.stdout = original_stdout
    __builtins__.input = original_input

if 'error' in locals():
  if isinstance(error, NameError):
    print("❌ Function 'get_started' not defined")
  else:
    print(type(error).__name__, "-", error)
else:
    if output.strip() == expected_output.strip():
        print("✅ Output matches!")
    else:
        print("#--- Your code output: ---#\n".center(72))
        print(output.strip() + "\n")
        print("#--- Expected output: ---#\n".center(72))
        print(expected_output.strip() + "\n")
        print("❌ Output does not match.")

    if test_function == 'words.txt':
        print("✅ Return value is correct: 'words.txt'")
    else:
        print(f"❌ Return value is incorrect: {test_function}")
# Out:
# ✅ Output matches!
# ✅ Return value is correct: 'words.txt'

# %% [markdown]
# #**Step 4: Define `list_of_words` function**
#
# 1.  This function takes a list of words, `read`, as an argument
# 2.  Creates a new empty list, `words_list`.
# 3.  Loops over each item in `read` and adds to new list.
# 4.  Returns the new list.

# %%
# Type your code below then run:

# %% [markdown]
# ---
# <details>
# <summary>💡 Hint</summary>
#
# *   Use list method `.append()`.
# </details>
#
# ---

# %% [markdown]
# Test your code:

# %%
# @title
#Click Run to test your code above
try:
    original = ["apple", "banana", "cherry"]
    new_list = list_of_words(original)
    if new_list == original:
        print("✅ Values match the original list")
    else:
        print("❌ Values do NOT match the original list")
    if new_list is not original:
        print("✅ Returned a new list (different object)")
    else:
        print("❌ Returned the original list (not a new list)")
    new_list.append("date")
    if "date" not in original:
        print("✅ Modifying new list does not change the original")
    else:
        print("❌ Modifying new list changed the original")
except NameError:
    print ("❌ Function 'list_of_words' not defined")
# Out:
# ❌ Function 'list_of_words' not defined

# %% [markdown]
# #**Step 5: Define 'get_random_word` function**
#
#
# 1.   This function takes a list `words` as an argument.
# 2.   The function picks a random position (index) in the list.
# 3.    Returns the word from the `words` list at that position.

# %%
# Type your code below then run:

# %% [markdown]
# ---
# <details>
# <summary>💡Hint</summary>
#
# *   Use `random.randrange()` or `random.randint()` to get random position/number. Store this number in a variable.
#
#     <details>
#     <summary>More</summary>
#
#       * `.randrange(start, stop) or (stop)` generates a number from start or 0 (default) to stop - 1 (start number inclusive, stop number not inclusive).
#
#       * `.randint(a, b)` generates a number from a to b (both numbers inclusive).
#
#       * Use len(words) to get the total number on items in the list `words`.
#
#       * Make sure the index number exists in the `words` list (index starts at 0 to len(words)-1).
#
#     </details>
#
# *   To return a word from the list of words, think about indexing/how to access an item from a list
#     <details>
#     <summary>More</summary>
#
#       * list[index]
#
#     </details>
#
# </details>
#
# ---

# %% [markdown]
# Test your code:

# %%
# @title
try:
  words = ["apple", "banana", "cherry", "grape", "melon"]
  result = get_random_word(words)
  if result in words:
      print("✅ Returned word is in the list")
  else:
      print("❌ Returned word is not in the list")
  results = set()
  for i in range(10):
      results.add(get_random_word(words))
  if len(results) > 1:
      print("✅ Function returns different words (randomness works)")
  else:
      print("⚠️ Only one word returned in 10 tries (might still be random, but unlikely)")
except NameError:
    print("❌ Function 'get_random_word' not defined")
# Out:
# ❌ Function 'get_random_word' not defined

# %% [markdown]
# #**Step 6: Define 'get_player_guess' function**
#
#
#
# 1.  Takes no arguments
# 2.  This function opens the file words.txt and reads all the words into a list called valid_words, where each word is stripped of whitespace and converted to lowercase.
#
# 3. The function then repeatedly prompts the user to enter a guess using a while True loop. The user input should also be converted to lowercase.
#
#     <details>
#     The words from the file and the user’s input are converted to lowercase to ensure consistency when comparing values during validation. This prevents mismatches (e.g., "HEllo" vs "hello"), allowing valid words to be recognised regardless of how the user types them.
#     </details>
#
#     The input is validated using the following conditions:
#
#     * The guess must be exactly 5 letters long
#
#     * The guess must contain only alphabetic characters
#
#     * The guess must exist in the list of valid words
#
#    If the input does not meet any of these conditions, print an appropriate error message and the user is prompted again.
#
# 5. Once a valid guess is entered, the function returns the guess in lowercase.

# %%
# Type your code below then run:

# %% [markdown]
# ---
# <details>
# <summary>💡 Hint</summary>
#
# * You need to read words from a file called `words.txt`. Think about how to open a file safely in Python.
#   Note: when you open a file you need to make sure to close it.
#
#   <details>
#   <summary>More</summary>
#
#   - You can use a `with open(...)` statement so the file is automatically closed after reading.
#
#   </details>
#
# * Once the file is open, you can loop through each line in the file to access the words.
#
#   <details>
#   <summary>More</summary>
#
#   - Each word may include extra whitespace or newline characters → use `strip()` to clean
#   - Convert each word to lowercase using `.lower()`
#   - Store the cleaned words in a list using a list comprehension
#
#     <details>
#     <summary>Details</summary>
#
#     - Basic list comprehension format:
#       `new_list = [expression for item in iterable]`
#
#       <details>
#       <summary>Example</summary>
#
#       ```python
#       fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
#
#       upper_fruits = []
#       for f in fruits:
#           upper_fruits.append(f.upper())
#       ```
#
#       is the same as:
#
#       ```python
#       upper_fruits = [f.upper() for f in fruits]
#       ```
#
#       </details>
#     </details>
#   </details>
#
# * To check if the number of letters is not 5 → use `len(...) != 5`
# * To check if the guess is not alphabetic → use `.isalpha()`
# * To check if the guess is not a valid word → use `not in`
#
# </details>
#
# ---

# %% [markdown]
# Test your code - simulating user input automatically:

# %%
# @title
import builtins
import io
import sys

def test_get_player_guess():
    test_cases = [
        {
            "name": "valid word first try",
            "inputs": ["apple"],
            "expected_return": "apple"
        },
        {
            "name": "invalid length then valid word",
            "inputs": ["app", "apple"],
            "expected_return": "apple"
        },
        {
            "name": "non-alphabetic then valid word",
            "inputs": ["12345", "apple"],
            "expected_return": "apple"
        },
        {
            "name": "invalid word then valid word",
            "inputs": ["zzzzz", "apple"],
            "expected_return": "apple"
        },
        {
            "name": "uppercase valid word",
            "inputs": ["APPLE"],
            "expected_return": "apple"
        }
    ]

    original_input = builtins.input
    original_stdout = sys.stdout

    for case in test_cases:
        print(f"Test: {case['name']}".center(50))
        #print(f"Inputs: {case['inputs']}")

        inputs_used = []
        inputs_iter = iter(case["inputs"])

        def mock_input(prompt):
            value = next(inputs_iter)
            inputs_used.append(value)
            return value

        builtins.input = mock_input
        sys.stdout = io.StringIO()

        try:
            result = get_player_guess()
            output = sys.stdout.getvalue()
        except Exception as e:
            result = f"ERROR: {type(e).__name__} - {e}"
            output = sys.stdout.getvalue()
        finally:
            builtins.input = original_input
            sys.stdout = original_stdout

        output_lines = [line for line in output.strip().split("\n") if line]

        for i, user_input in enumerate(inputs_used):
            print(f"\nInput: '{user_input}'")
            if i < len(output_lines):
                print("Printed output:")
                print(output_lines[i])

        print(f"Returned: {result}")

        if result == case["expected_return"]:
            print("✅ Return value correct")
        else:
            print(f"❌ Return value incorrect (expected {case['expected_return']})")

        print("-" * 50)

# run test
test_get_player_guess()

# %% [markdown]
# ###**What you would have learnt in this project:**
#
#
# *   Opening, reading, and closing files
# *   input
# *   Output formatting: f-strings
#
#     ```
#     name = "Student"
#     age = 1
#     print(f"Name: {name}, Age: {age}")
#     #Name: Student, Age: 1
#     ```
# *   list comphrehension
#     ```
#     num = [1, 2, 3, 4, 5]
#     double_list = [x * 2 for x in num]
#     ```
#
# *   persistance
